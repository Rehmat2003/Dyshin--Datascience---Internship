# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("automobile_data.csv")
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
df.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
df.shape
# Out:
# (61, 10)

# %%
df.columns
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
df.describe()
# Out:
#            index  wheel-base      length  horsepower  average-mileage  \
# count  61.000000   61.000000   61.000000   61.000000        61.000000
# mean   40.885246   98.481967  173.098361  107.852459        25.803279
# std    25.429706    6.679234   14.021846   53.524398         8.129821
# min     0.000000   88.400000  141.100000   48.000000        13.000000
# 25%    18.000000   94.500000  159.100000   68.000000        19.000000
# 50%    39.000000   96.300000  171.200000  100.000000        25.000000
# 75%    61.000000  101.200000  177.300000  123.000000        31.000000
# max    88.000000  120.900000  208.100000  288.000000        47.000000
#
#               price
# count     58.000000
# mean   15387.000000
# std    11320.259841
# min     5151.000000
# 25%     6808.500000
# 50%    11095.000000
# 75%    18120.500000
# max    45400.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=61, step=1)

# %%
df.dtypes
# Out:
# index                 int64
# company              object
# body-style           object
# wheel-base          float64
# length              float64
# engine-type          object
# num-of-cylinders     object
# horsepower            int64
# average-mileage       int64
# price               float64
# dtype: object

# %%
df.describe().sum()
# Out:
# index                 333.314952
# wheel-base            667.461201
# length               1104.920207
# horsepower            849.376857
# average-mileage       229.933100
# price              113340.259841
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
num_col = df.select_dtypes(include=np.number).columns

# %%
cat_col = df.select_dtypes(include=np.number).columns

# %%
for col in num_col:
    df[col].fillna(df[col].median(),inplace=True)

for col in cat_col:
    df[col].fillna(df[col].mode(),inplace=True)
# Out:
# C:\Users\MANJOORHUSEN\AppData\Local\Temp\ipykernel_7676\1412792612.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\MANJOORHUSEN\AppData\Local\Temp\ipykernel_7676\1412792612.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated("price").any()
# Out:
# np.True_

# %%
df.duplicated("company").any()
# Out:
# np.True_

# %%
df.drop_duplicates(inplace=True)

# %%
for col in num_col:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3-Q1

    #limits

    lower = Q1-1.5*IQR
    upper = Q3+1.5*IQR

    #Outlier
    outlier = df[(df[col]<lower)|(df[col]>upper)]

    print(col," outlier:",len(outlier))
# Out:
# index  outlier: 0
# wheel-base  outlier: 4
# length  outlier: 1
# horsepower  outlier: 4
# average-mileage  outlier: 0
# price  outlier: 8

# %% [markdown]
# Histogram plotting

# %%
import seaborn as sns

# %%
sns.histplot(df['horsepower'])
# Out:
# <Axes: xlabel='horsepower', ylabel='Count'>

# %% [markdown]
# Bar Graph

# %%
sns.barplot(data=df,x='num-of-cylinders',y='price')
# Out:
# <Axes: xlabel='num-of-cylinders', ylabel='price'>

# %% [markdown]
# Pie chart

# %%
import matplotlib.pyplot as plt
x = df['company'].value_counts()
plt.pie(x.values, 
        labels = x.index,
        autopct = '%1.1f%%')
plt.title("Company Distribution")
plt.show()

# %% [markdown]
# Boxplot

# %%
sns.boxplot(x=df['price'])
plt.title("Price Outliers")
plt.show()

# %% [markdown]
# Heatmap

# %%
sns.heatmap(df.select_dtypes(include=['number']).corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Count plot

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df,x='company',hue='average-mileage')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Scatter plot

# %%
sns.scatterplot(data=df,x="engine-type",y="price")
# Out:
# <Axes: xlabel='engine-type', ylabel='price'>

# %% [markdown]
# Pairplot

# %%
sns.pairplot(df)

# %%
nan_indexes = df[df.price.isnull()].index
df.drop(nan_indexes, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.to_csv("clean_automobile_data.csv", index=False)

# %%
df[df.price == df.price.max()][["company", "price"]]
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
df.company.value_counts()
# Out:
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: count, dtype: int64

# %%
df.groupby("company")["price"].max()
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu            11095.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %% [markdown]
# 5 Cars with lowest price

# %%
df.sort_values("price").head(5)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 13     16   chevrolet  hatchback        88.4   141.1           l
# 27     36       mazda  hatchback        93.1   159.1         ohc
# 48     66      toyota  hatchback        95.7   158.7         ohc
# 36     49  mitsubishi  hatchback        93.7   157.3         ohc
# 28     37       mazda  hatchback        93.1   159.1         ohc
#
#    num-of-cylinders  horsepower  average-mileage   price
# 13            three          48               47  5151.0
# 27             four          68               30  5195.0
# 48             four          62               35  5348.0
# 36             four          68               37  5389.0
# 28             four          68               31  6095.0

# %%
df.nsmallest(5, "price")
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 13     16   chevrolet  hatchback        88.4   141.1           l
# 27     36       mazda  hatchback        93.1   159.1         ohc
# 48     66      toyota  hatchback        95.7   158.7         ohc
# 36     49  mitsubishi  hatchback        93.7   157.3         ohc
# 28     37       mazda  hatchback        93.1   159.1         ohc
#
#    num-of-cylinders  horsepower  average-mileage   price
# 13            three          48               47  5151.0
# 27             four          68               30  5195.0
# 48             four          62               35  5348.0
# 36             four          68               37  5389.0
# 28             four          68               31  6095.0

# %% [markdown]
# Cars with the Lowest and Highest Horsepower

# %%
df[df.horsepower == df.horsepower.min()]
# Out:
#     index    company body-style  wheel-base  length engine-type  \
# 13     16  chevrolet  hatchback        88.4   141.1           l
#
#    num-of-cylinders  horsepower  average-mileage   price
# 13            three          48               47  5151.0

# %%
df[df.horsepower == df.horsepower.max()]
# Out:
#     index  company body-style  wheel-base  length engine-type  \
# 47     63  porsche  hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 47            eight         288               17  11095.0

# %% [markdown]
# DAY-24

# %% [markdown]
# Average Mileage for all thea Car present

# %%
df["average-mileage"].mean()
# Out:
# np.float64(25.80327868852459)

# %% [markdown]
# Display Car which has Mileage greater than 30

# %%
df[df["average-mileage"] > 30]
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 13     16   chevrolet  hatchback        88.4   141.1           l
# 14     17   chevrolet  hatchback        94.5   155.9         ohc
# 15     18   chevrolet      sedan        94.5   158.8         ohc
# 16     19       dodge  hatchback        93.7   157.3         ohc
# 17     20       dodge  hatchback        93.7   157.3         ohc
# 22     31       isuzu      sedan        94.5   155.9         ohc
# 23     32       isuzu      sedan        94.5   155.9         ohc
# 28     37       mazda  hatchback        93.1   159.1         ohc
# 29     38       mazda  hatchback        93.1   159.1         ohc
# 31     43       mazda      sedan       104.9   175.0         ohc
# 36     49  mitsubishi  hatchback        93.7   157.3         ohc
# 37     50  mitsubishi  hatchback        93.7   157.3         ohc
# 40     53      nissan      sedan        94.5   165.3         ohc
# ...

# %%
df.groupby("company")["horsepower"].mean()
# Out:
# company
# alfa-romero      125.333333
# audi             109.250000
# bmw              144.833333
# chevrolet         62.666667
# dodge             68.000000
# honda             92.333333
# isuzu             72.666667
# jaguar           204.666667
# mazda             75.400000
# mercedes-benz    153.500000
# mitsubishi        78.000000
# nissan            82.800000
# porsche          234.000000
# toyota            75.428571
# volkswagen        72.250000
# volvo            114.000000
# Name: horsepower, dtype: float64

# %%
df["average-mileage"].max()
# Out:
# 47
