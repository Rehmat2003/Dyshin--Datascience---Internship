# %%
#variable
x=7
print(x)
# Out:
# 7

# %%
y="hello"
print(y)
# Out:
# hello

# %%
#pascal case
MyVar="python"
print(MyVar)
# Out:
# python

# %%
#camel case
myvar="python"
print(myvar)
# Out:
# python

# %%
#snake case
my_var="python"
print(my_var)

# my var will not work buz of the space
#2my_var will also not work bcuz the variable doesnt start with a number
# Out:
# python

# %%
x="apple"
y="apple"
print (x)
print(y)
# Out:
# apple
# apple

# %%
x="apple"
x="kiwi"
print(x)
#it will give kiwi becuz its overwriting on the first x value with kiwi
# Out:
# kiwi

# %%
#identifying datatype
x=10
type(x)
# Out:
# int

# %%
#string
y="maha"
type(y)
# Out:
# str

# %%
#bool
z=True
type(z)
# Out:
# bool

# %%
#float
x=10.0
type(x)
# Out:
# float

# %%
x=1j
type(x)
# Out:
# complex

# %%
x=["a","b"]
type(x)
# Out:
# list

# %%
x=("a","b")
type(x)
# Out:
# tuple

# %%
x={'a':'b','c':'d'}
type(x)
# Out:
# dict

# %%
x={'a','c'}
type(x)
# Out:
# set

# %%
word="maha"
print(word[-2]) #indexx
print(len(word))  #length
# Out:
# h
# 4

# %%
#checkstring
#produces output in boolean
text="good morning"
print("good" in text)
# Out:
# True

# %%
#check if not
text="good morning"
print("good" not in text)
print("Good" not in text)
# Out:
# False
# True

# %%
#concatenation
x="hi"
y="bye"
print(x+y)
print(x+" "+y)
print(x,y)
# Out:
# hibye
# hi bye
# hi bye

# %%
#slice
x="gelloo"
print(slice(x))
y="i am happy"
print(y[2:5])
print(y[2:10]) #not preffered
print(y[2:])
print(y[:5])
#last character will be excluded
# Out:
# slice(None, 'gelloo', None)
# am
# am happy
# am happy
# i am

# %%
x="HELLO"
print(x.lower())
print(x.lower()[4])
# Out:
# hello
# o

# %%
x="maha"
print(x.upper())
x="HELLO"
print(x.lower()[0])
# Out:
# MAHA
# h

# %%
#replace 
x="aahaa"
print(x.replace('a','m'))
print(x.replace('h','M'))
#to replace only first a
print(x.replace('a','M')[0])
print(x.replace('a','M',1))
# Out:
# mmhmm
# aaMaa
# M
# Mahaa
