# %%
#boolean
print(10==10)
# Out:
# True

# %%
print(10<1)
# Out:
# False

# %%
#list
l=[1,2,3]
l.append(5)
print(l)
print(type(list))
# Out:
# [1, 2, 3, 5]
# <class 'type'>

# %%
l.remove(5)
print(l)
# Out:
# [1, 2, 3]

# %%
print(l[2])
print(l)
# Out:
# 3
# [1, 2, 3]

# %%
l.remove(l[1])
print(l)
# Out:
# [1]

# %%
print(len(l))
# Out:
# 1

# %%
print(l[0])
# Out:
# 1

# %%
n=[25,27,30,49,12]
print(n[0:3])
# Out:
# [25, 27, 30]

# %%
print(n[2:])
# Out:
# [30, 49, 12]

# %%
a=[12,"apple",32.4,True]
print(a)
print(type(a))
# Out:
# [12, 'apple', 32.4, True]
# <class 'list'>

# %%
fruit=['apple','strawberry','kiwi']

# %%
merge=n+fruit
print(merge)
# Out:
# [25, 27, 30, 49, 12, 'apple', 'strawberry', 'kiwi']

# %%
l_merge=[n,fruit]
print(l_merge)
# Out:
# [[25, 27, 30, 49, 12], ['apple', 'strawberry', 'kiwi']]

# %%
n.extend([10,15])
print(n)
# Out:
# [25, 27, 30, 49, 12, 10, 15, 10, 15]

# %%
n.sort()
print(n)
# Out:
# [10, 10, 12, 15, 15, 25, 27, 30, 49]

# %%
n.sort(reverse=True)
print(n)
# Out:
# [49, 30, 27, 25, 15, 15, 12, 10, 10]

# %%
n.reverse()
print(n)
# Out:
# [49, 30, 27, 25, 15, 15, 12, 10, 10]

# %%
#tuple
t=(21,30,45,22)
print(type(t))
# Out:
# <class 'tuple'>

# %%
t[1]
# Out:
# 30

# %%
t=(21,30,45,22,30,44,99,30)
print(t.count(30))
# Out:
# 3

# %%
#index
print(t.index(30))
# Out:
# 1

# %%
#set
s={1,2,3,4,5}
print(type(s))
# Out:
# <class 'set'>

# %%
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#add
s.add(6)
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s.remove(2)
print(s)
# Out:
# {1, 3, 4, 5, 6}

# %% [raw]
# s.clear()

# %%
print(s)
# Out:
# {1, 3, 4, 5, 6}

# %%
#union
x={1,2,3,4}
y={2,3,4,5,6}
print(x.union(y))
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#intersetion
x={1,2,3,4}
y={2,3,4,5,6}
print(x.intersection(y))
# Out:
# {2, 3, 4}

# %%
#setdifference
x={1,2,3,4}
y={2,3,4,5,6}
print(x.difference(y))
print(y.difference(x))
# Out:
# {1}
# {5, 6}
