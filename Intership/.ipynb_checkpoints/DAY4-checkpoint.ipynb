# %%
day=2
match day:
    case 1:
        print("M")
    case 2:
        print("T")
    case 2:
        print("W")
# Out:
# T

# %%
#Dictionaries
data={1:'apple',2:'kiwi'}

# %%
print(type(data))
print(data)
print(data[2])
# Out:
# <class 'dict'>
# {1: 'apple', 2: 'kiwi'}
# kiwi

# %%
data.get(1)
# Out:
# 'apple'

# %%
keys=['A','B','C']
values=['python','java','js']

data = dict(zip(keys,values))
data
# Out:
# {'A': 'python', 'B': 'java', 'C': 'js'}

# %%
keys=['A','B','C']
values=['python','java','js']

data = dict(zip(sorted(keys),sorted(values)))
data
# Out:
# {'A': 'java', 'B': 'js', 'C': 'python'}

# %%
#add
data['D']="react"
data
# Out:
# {'A': 'java', 'B': 'js', 'C': 'python', 'D': 'react'}

# %%
#update
data.update({"C":"C++"})
data
# Out:
# {'A': 'java', 'B': 'js', 'C': 'C++', 'D': 'react'}

# %%
#delete
del data["A"]
data
# Out:
# {'B': 'js', 'C': 'C++', 'D': 'react'}

# %%
#operators

x=5
y=7
z=x+y
print(z)
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x//y)
print(x%y)
# Out:
# 12
# 12
# -2
# 35
# 0.7142857142857143
# 0
# 5

# %%
x=5
x+=20
x
# Out:
# 25

# %%
x=5
x-=20
x
# Out:
# -15

# %%
x=2
x*=7
x
# Out:
# 14

# %%
#comparison

x=10
y=23

print(x==y)
print(x!=y)
print(x>=y)
print(x<=y)
# Out:
# False
# True
# False
# True

# %%
#logical operators
#and

x=5
print(x>0 and x==5)
print(x>0 and x<=5)
# Out:
# True
# True

# %%
#or

x=10
print(x<=8 or x>=11)
print(x<=8 or x>=10)
# Out:
# False
# True

# %%
#not
x=10
print(not(x>10 and x>=10))
# Out:
# True
